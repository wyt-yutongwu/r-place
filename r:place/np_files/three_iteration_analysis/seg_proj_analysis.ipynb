# %%
#import basic libraries

import csv
import sys
import os
import math
import re
import numpy as np
import numpy.linalg as npla
import scipy
from scipy import sparse
from scipy import linalg
import scipy.sparse.linalg as spla
import matplotlib.pyplot as plt 
from matplotlib import cm
import matplotlib.mlab as mlab
from mpl_toolkits.mplot3d import axes3d
sys.path.append("../Python_code") # go to parent dir
from canvas_vis import *

# %%
input_file = "../data/test_sorted_proj.csv"

# %%
with open(input_file,'r') as file:
    reader = csv.reader(file)
    row1 = next(reader)
    row2 = next(reader)

# %%
time = row1[0]

# %%
t_s = time.split("_")

# %%
time = t_s[0]

# %%
lab = int(t_s[1])

# %%
time
# Out:
# '1491014068000'

# %%
tst_canvas = np.array(255*np.ones((1001,1001,3)))

# %%
canvas = np.load("/home/yw180/place/data/canvas/canvas_"+str(time)+".npy")
label = np.load("/scratch/yw180/place/data/labels/label_"+str(time)+".npy")

# %%
for i in range(0, 1001):
    for j in range(0, 1001):
        if label[j,i] == lab:
            tst_canvas[j,i] = canvas[j,i]

# %%
plt.figure(frameon=False, figsize = (100,100))
fig, a = plt.subplots()

a.axis('off')

plt.imshow(tst_canvas)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
time = row2[0]

# %%
t_s = time.split("_")
time = t_s[0]
lab = int(t_s[1])
tst_canvas = np.array(255*np.ones((1001,1001,3)))
canvas = np.load("/home/yw180/place/data/canvas/canvas_"+str(time)+".npy")
label = np.load("/scratch/yw180/place/data/labels/label_"+str(time)+".npy")

# %%
for i in range(0, 1001):
    for j in range(0, 1001):
        if label[j,i] == lab:
            tst_canvas[j,i] = canvas[j,i]

# %%
plt.figure(frameon=False, figsize = (100,100))
fig, a = plt.subplots()

a.axis('off')

plt.imshow(tst_canvas)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
